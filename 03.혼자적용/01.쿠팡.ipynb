# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

data = [] ;

url = 'https://www.coupang.com/np/search?component=&q=%EB%AF%B8%EB%8B%88%EC%98%A4%EB%B8%90&channel=user'
response = requests.get(f"{url}")

html = response.text
soup = BeautifulSoup(html,'html.parser')
soup.select('.search-product-wrap.adjust-spacing')
# totalCnt = len(soup.select('.store-pagination > li > a'))
# print(totalCnt)
# data = [] ;

# for i in range(1,totalCnt+1):
#     print(i)
#     pagingResponse = requests.get(f"{url}&page={i}")
#     html02 = pagingResponse.text
#     soup02 = BeautifulSoup(html02,'html.parser')
#     items = soup02.select(".product")
#     for item in items : 
#         category = item.select_one(".product-category").text
#         name = item.select_one(".product-name").text
#         link = item.select_one(".product-name > a ").attrs['href']
#         price = soup.select_one(".product-price").text.strip()
#         #print(category,name,link,price)
#         data.append([category,name,link,price])
# print(data)
# 데이터 프레임 만들기
# df = pd.DataFrame(data,columns=['카테고리','상품명','상세페이지 링크','가격'])
# df

# #엑셀저장
# df.to_excel('result.xlsx')
# 번호 자동부여 X 엑셀
# df.to_excel('result02.xlsx',index=False)

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get("https://www.csi.go.kr/acd/acdCaseView.do?case_no=27442")
html = response.text
soup = BeautifulSoup(html,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 8]> <html lang="en" class="ie8 no-js"> <![endif]-->
# <!--[if IE 9]> <html lang="en" class="ie9 no-js"> <![endif]-->
# <!--[if !IE]><!-->
# <html lang="ko">
# <!--<![endif]-->
# <!-- head 시작 -->
# <head>
# <title>건설사고 &gt; 사고사례 &gt; 사고사례 조회</title>
# <link href="https://www.csi.go.kr/" rel="canonical"/>
# <meta content="건설공사 안전관리 종합정보망은 건설공사 안전관리에 필요한 정보를 통합(연계) 관리하고 공동활용을 촉진함으로써 건설현장의 안전을 확보합니다." name="description"/>
# <meta content="website" property="og:type"/>
# <meta content="건설공사 안전관리 종합정보망" property="og:title"/>
# <meta content="건설공사 안전관리 종합정보망은 건설공사 안전관리에 필요한 정보를 통합(연계) 관리하고 공동활용을 촉진함으로써 건설현장의 안전을 확보합니다." property="og:description"/>
# <meta content="https://www.csi.go.kr/com/img/common/header/logo.png" property="og:image"/>
# <meta content="https://www.csi.go.kr/" property="og:url"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="건설공사 안전관리 종합정보망" name="twitter:title"/>
# <meta content="건설공사 안전관리 종합정보망은 건설공사 안전관리에 필요한 정보를 통합(연계) 관리하고 공동활용을 촉진함으로써 건설현장의 안전을 확보합니다." name="twitter:description"/>
# <meta content="https://www.csi.go.kr/com/img/common/header/logo.png" name="twitter:image"/>
# <meta content="https://www.csi.go.kr/" name="twitter:domain"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
# <link href="/com/favicon.ico" rel="shortcut icon">
# <!-- 공통 -->
# <link href="/com/plugins/font-awesome/css/font-awesome.css" rel="stylesheet" type="text/css"/>
# <link href="/com/plugins/simple-line-icons/simple-line-icons.css" rel="stylesheet" type="text/css"/>
# <script src="/com/plugins/jquery.min.js" type="text/javascript"></script>
# <script src="/com/plugins/js.cookie.min.js" type="text/javascript"></script>
# <script src="/com/js/app.js" type="text/javascript"></script>
# <!-- bootstrap -->
# <link href="/com/plugins/bootstrap/css/bootstrap.min.css" rel="stylesheet" type="text/css"/>
# <script src="/com/plugins/bootstrap/js/bootstrap.min.js" type="text/javascript"></script>
# <!-- bootstrap-datepicker -->
# <link href="/com/plugins/bootstrap-datepicker/css/bootstrap-datepicker3.css" rel="stylesheet" type="text/css"/>
# <link href="/com/plugins/bootstrap-timepicker/css/bootstrap-timepicker.css" rel="stylesheet" type="text/css"/>
# <link href="/com/plugins/bootstrap-datetimepicker/css/bootstrap-datetimepicker.css" rel="stylesheet" type="text/css"/>
# <script src="/com/plugins/bootstrap-datepicker/js/bootstrap-datepicker.js" type="text/javascript"></script>
# <script src="/com/plugins/bootstrap-datepicker/locales/bootstrap-datepicker.kr.min.js" type="text/javascript"></script>
# <script src="/com/plugins/bootstrap-timepicker/js/bootstrap-timepicker.js" type="text/javascript"></script>
# <script src="/com/plugins/bootstrap-datetimepicker/js/bootstrap-datetimepicker.js" type="text/javascript"></script>
# <script src="/com/plugins/bootstrap-datetimepicker/js/locales/bootstrap-datetimepicker.kr.js" type="text/javascript"></script>
# <script src="/com/js/bootstrap-datepicker.kr.js" type="text/javascript"></script>
# <script src="/com/js/components-date-time-pickers.js?ver=1.0" type="text/javascript"></script>
# <!-- bootstrap-fileinput -->
# <link href="/com/plugins/bootstrap-fileinput/bootstrap-fileinput.css" rel="stylesheet" type="text/css"/>
# <script src="/com/plugins/bootstrap-fileinput/bootstrap-fileinput.js" type="text/javascript"></script>
# <!-- bootstrap-tabdrop -->
# <script src="/com/plugins/bootstrap-tabdrop/js/bootstrap-tabdrop.js" type="text/javascript"></script>
# <!-- jstree -->
# <!--
# 		<link href="/com/plugins/jstree/dist/themes/default/style.css" rel="stylesheet" type="text/css" />
# 		<script src="/com/plugins/jstree/dist/jstree.js" type="text/javascript"></script>
# 		<script src="/com/js/ui-tree.js" type="text/javascript"></script>
#  		-->
# <!-- datatables-managed -->
# <!--
# 		<script src="/com/js/datatable.js" type="text/javascript"></script>
# 		<script src="/com/plugins/datatables/datatables.min.js" type="text/javascript"></script>
# 		<script src="/com/plugins/datatables/plugins/bootstrap/datatables.bootstrap.js" type="text/javascript"></script>
# 		<script src="/com/js/table-datatables-managed.min.js" type="text/javascript"></script>
# 		-->
# <!-- bootstrap-touchspin -->
# <link href="/com/plugins/bootstrap-touchspin/bootstrap.touchspin.css" rel="stylesheet" type="text/css"/>
# <script src="/com/plugins/bootstrap-touchspin/bootstrap.touchspin.js" type="text/javascript"></script>
# <script src="/com/js/components-bootstrap-touchspin.js" type="text/javascript"></script>
# <!-- bootstrap-switch -->
# <link href="/com/plugins/bootstrap-switch/css/bootstrap-switch.min.css" rel="stylesheet" type="text/css"/>
# <script src="/com/plugins/bootstrap-switch/js/bootstrap-switch.min.js" type="text/javascript"></script>
# <script src="/com/js/components-bootstrap-switch.min.js" type="text/javascript"></script>
# <!-- bootstrap-toastr -->
# <link href="/com/plugins/bootstrap-toastr/toastr.css" rel="stylesheet" type="text/css"/>
# <script src="/com/plugins/bootstrap-toastr/toastr.js" type="text/javascript"></script>
# <script src="/com/js/ui-toastr.js" type="text/javascript"></script>
# <!-- jquery-ui -->
# <script src="/com/plugins/jquery-ui/jquery-ui.min.js" type="text/javascript"></script>
# <script src="/com/js/ui-modals.js" type="text/javascript"></script>
# <!-- pace-loading -->
# <script src="/com/plugins/pace-1.0.2/pace.js" type="text/javascript"></script>
# <link href="/com/plugins/pace-1.0.2/themes/blue/pace-theme-loading-bar.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
# 	        paceOptions = {
# 	            ajax: true, // enabled
# 	            document: true, // enabled
# 	            eventLag: false // disabled
# 	        };
#
# 	        $(function() {
# 	        	//$(document).ajaxStart(function() { Pace.restart(); });<!-- pace-loading -->
# 	        });
#         </script>
# <!-- splitter -->
# <link href="/com/plugins/jquery-touch-splitter/css/touchsplitter.css" rel="stylesheet" type="text/css"/>
# <script src="/com/plugins/jquery-touch-splitter/js/jquery.touchsplitter.js" type="text/javascript"></script>
# <!-- amcharts -->
# <script src="/com/plugins/amcharts/amcharts.js" type="text/javascript"></script>
# <script src="/com/plugins/amcharts/serial.js" type="text/javascript"></script>
# <script src="/com/plugins/amcharts/pie.js" type="text/javascript"></script>
# <script src="/com/plugins/amcharts/plugins/export/export.js" type="text/javascript"></script>
# <script src="/com/plugins/amcharts/themes/light.js" type="text/javascript"></script>
# <!-- jquery-slimscroll -->
# <script src="/com/plugins/jquery-slimscroll/jquery.slimscroll.min.js" type="text/javascript"></script>
# <!-- FlexSlider -->
# <link href="/com/plugins/flex-slider-2/css/flexslider.css" rel="stylesheet" type="text/css"/>
# <script src="/com/plugins/flex-slider-2/js/modernizr.js"></script>
# <script src="/com/plugins/flex-slider-2/js/jquery.flexslider.js"></script>
# <script src="/com/plugins/flex-slider-2/js/jquery.easing.js"></script>
# <script src="/com/plugins/flex-slider-2/js/jquery.mousewheel.js"></script>
# <script src="/com/plugins/flex-slider-2/js/demo.js"></script>
# <!-- layout & themes -->
# <link href="/com/skin/layout/css/components_compact.css?ver=1.0" id="style_components" rel="stylesheet" type="text/css"/>
# <link href="/com/skin/layout/css/plugins.css?ver=1.0" rel="stylesheet" type="text/css"/>
# <link href="/com/skin/layout/css/layout_compact.css?ver=1.0" rel="stylesheet" type="text/css"/>
# <script src="/com/skin/layout/scripts/layout.js" type="text/javascript"></script>
# <!-- customizing -->
# <script src="/com/js/common.js" type="text/javascript"></script>
# <script src="/com/js/commonMsg.js" type="text/javascript"></script>
# <link href="/com/css/default.css?ver=1.3" rel="stylesheet" type="text/css"/>
# <link href="/com/css/custom.css?ver=1.2" rel="stylesheet" type="text/css"/>
# <link href="/com/css/login.css?ver=1.0" rel="stylesheet" type="text/css"/>
# <!-- main renewal -->
# <link href="/com/css/main_renewal.css?ver=1.2" rel="stylesheet" type="text/css"/>
# <link href="/com/css/page_search.css?ver=1.0" rel="stylesheet" type="text/css"/>
# <!-- sinjin-custom -->
# <script src="/com/js/jquery.form.js" type="text/javascript"></script>
# <script src="/com/js/util_common.js?ver=2.6" type="text/javascript"></script>
# <script src="/com/js/util_datetime.js" type="text/javascript"></script>
# <script src="/com/js/util_popup.js?ver=1.6" type="text/javascript"></script>
# <script src="/com/js/util_string.js" type="text/javascript"></script>
# <script src="/com/js/jquery.table2excel.js" type="text/javascript"></script>
# <!-- innorix -->
# <link href="/com/innorix/innorix.css" rel="stylesheet"/>
# <script src="/com/innorix/innorix.js"></script>
# <!-- introjs -->
# <link href="/com/introjs/introjs.min.css" rel="stylesheet"/>
# <script src="/com/introjs/intro.min.js"></script>
# <!-- moment -->
# <script src="/com/js/moment/moment.min.js"></script>
# <script src="/com/js/moment/ko.js"></script>
# <!-- 검색엔진 js -->
# <script src="/com/js/search/diquest.js"></script>
# <!-- lodash js -->
# <script src="/com/js/lodash.min.js" type="text/javascript"></script>
# <!-- 건설기계 e 마당 관련 -->
# <script src="/script/cro/equipmentSpec.js?ver=20240517160320" type="text/javascript"></script>
# <script src="/script/cro/region.js?ver=20240517160320" type="text/javascript"></script>
# <script src="/script/cro/equipmentSpecEtc.js?ver=20240517160320" type="text/javascript"></script>
# <script src="/script/cro/cro_common.js?ver=20240517160320" type="text/javascript"></script>
# <script src="/script/sas/sas.js?ver=20240517160320" type="text/javascript"></script>
# <!-- 가상계좌 -->
# <script src="https://js.tosspayments.com/v1/payment"></script>
# <script language="javascript">
#
#        		function moveUrl(){
# 				console.log($('#relationSite option:selected').val());
# 				if($('#relationSite option:selected').val() != ''){
# 					var win = window.open($('#relationSite option:selected').val(), '_blank');
# 					win.focus();
# 				}
#        		}
#
# 	       	function noAccess() {
# 	       		alert('접근 권한이 없습니다.');
# 	       	}
#
# 	     // left 메뉴 출력(권한 적용)
# 			function fnLeftMenuCreate(systemCd){
# 				$.ajax({
# 					       url         : "/com/selectLeftMenuAjax.do?system_cd="+systemCd,
# 					       contentType : "application/x-www-form-urlencoded;charset=UTF-8",
# 					       type        : "post",
# 					       dataType    : "json",
# 					       data		   : "{}",
# 					       success     : function(rstData, status){
# 											if(status == "success"){
# 												var arrLength = rstData.rtnList.length;
# 												var topMenuId = $("#pageSidebarMenu");
# 												if(arrLength > 0){
#
# 													var mainMenuId = "";
# 													var mainMenuContent = "";
# 													var subMenuId = "";
# 													var subMenuContent = "";
# 													var subMenuArea = "";
# 													var DefaultPageUrl = "";
# 													var arrowMark = "";
# 													var selectYn = "";
# 													var activeYn = "";
#
# 													//3레벨 서브메뉴아이디
# 													var level2MenuId = "";
# 													var thirdMenuId = "";
# 													var thirdMenuArea = "";
#
# 													//up level id
# 													var level_1_id = "";
# 													var level_2_id = "";
#
# 													for (var i=0; i < arrLength; i++) {
# 														var rowObj 		= rstData.rtnList[i];
#
# 														if(rowObj.menu_lvl == 1) {
#
# 															if(rowObj.default_page_url != "") {
# 																DefaultPageUrl = rowObj.default_page_url;
# 															} else {
# 																DefaultPageUrl = "javascript:;";
# 															}
#
# 															if(rowObj.submenu_cnt > 0) {
# 																arrowMark = "<span class='arrow'></span>";
# 															} else {
# 																arrowMark = "";
# 															}
#
# 															if(rowObj.menu_id=="ACD00147" || rowObj.menu_id=="" || rowObj.menu_id=="") {
# 																activeYn = "active";
# 																//arrowMark = "<span class='arrow open'></span>";
# 															} else {
# 																activeYn = "";
# 															}
#
# 															if(rowObj.popup_yn=="Y") {
# 																mainMenuContent = $("<li class='nav-item "+activeYn+"' id='mainMenu"+i+"' style='word-break:keep-all;word-wrap:break-word;'><a href='javascript:open_menuUrl(\""+rowObj.default_page_url+"\");' class='nav-link nav-toggle'><span class='title'>"+rowObj.menu_nm+"</span>"+arrowMark+" <img src='/com/img/common/icon/icon_popup_url.png' alt='icon' width=10 height=10></a></li>");
# 															} else {
# 																mainMenuContent = $("<li class='nav-item "+activeYn+"' id='mainMenu"+i+"' style='word-break:keep-all;word-wrap:break-word;'><a href='"+DefaultPageUrl+"' class='nav-link nav-toggle'><span class='title'>"+rowObj.menu_nm+"</span>"+arrowMark+"</a></li>");
# 															}
#
# 															$(topMenuId).append(mainMenuContent);
# 															mainMenuId = $("#mainMenu"+i);
#
# 															if(rowObj.submenu_cnt > 0) {
# 																subMenuArea = $("<ul class='sub-menu' id='subMenu"+i+"'></ul>");
# 																$(mainMenuId).append(subMenuArea);
# 																subMenuId = $("#subMenu"+i);
# 															}
#
# 															level_1_id = rowObj.menu_id;
#
# 														} else if(rowObj.menu_lvl == 2) {
#
# 															if(rowObj.default_page_url != "") {
# 																DefaultPageUrl = rowObj.default_page_url;
# 															} else {
# 																DefaultPageUrl = "javascript:;";
# 															}
#
# 															if(rowObj.submenu_cnt > 0) {
# 																arrowMark = "<span class='arrow'></span>";
# 															} else {
# 																arrowMark = "";
# 															}
#
# 															if(rowObj.menu_id=="ACD00147" || rowObj.menu_id=="" ) {
# 																activeYn = "active";
# 																selectYn = "selected";
# 																if(rowObj.submenu_cnt > 0) arrowMark = "<span class='arrow open'></span>";
# 															} else {
# 																activeYn = "";
# 																selectYn = "";
# 															}
#
# 															if(rowObj.popup_yn=="Y") {
# 																subMenuContent = $("<li class='nav-item "+activeYn+"' id='level2Menu"+i+"'><a href='javascript:open_menuUrl(\""+rowObj.default_page_url+"\");' class='nav-link nav-toggle'><span class='title'>"+rowObj.menu_nm+" <img src='/com/img/common/icon/icon_popup_url.png' alt='icon' width=10 height=10></span><span class='"+selectYn+"'></span></a></li>");
# 															} else {
# 																//subMenuContent = $("<li class='nav-item "+activeYn+"'><a onclick='javascript:href=\""+rowObj.default_page_url+"\"' class='nav-link nav-toggle'><span class='title'>"+rowObj.menu_nm+"</span><span class='"+selectYn+"'></span></a></li>");
# 																subMenuContent = $("<li class='nav-item "+activeYn+"' id='level2Menu"+i+"'><a href='"+DefaultPageUrl+"' class='nav-link nav-toggle'><span class='title'>"+rowObj.menu_nm+"</span><span class='"+selectYn+"'></span>"+arrowMark+"</a></li>");
# 															}
#
# 															$(subMenuId).append(subMenuContent);
# 															level2MenuId = $("#level2Menu"+i);
#
# 															if(rowObj.submenu_cnt > 0) {
# 																//thirdMenuArea = $("<ul class='sub-menu' id='thirdMenu"+i+"'></ul>");
# 																thirdMenuArea = $("<ul class='sub-menu sub-menu-depth3' id='thirdMenu"+i+"' style='padding-top: 0px; padding-bottom: 0px;'></ul>");
# 																$(level2MenuId).append(thirdMenuArea);
# 																thirdMenuId = $("#thirdMenu"+i);
# 															}
#
# 														} else if(rowObj.menu_lvl == 3) {
#
# 															if(rowObj.menu_id=="ACD00147") {
# 																activeYn = "active";
# 																selectYn = "selected";
# 															} else {
# 																activeYn = "";
# 																selectYn = "";
# 															}
#
# 															if(rowObj.popup_yn=="Y") {
# 																//subMenuContent = $("<li class='nav-item "+activeYn+" padL20'><a href='javascript:open_menuUrl(\""+rowObj.default_page_url+"\");' class='nav-link nav-toggle'><span class='title'>"+rowObj.menu_nm+" <img src='/com/img/common/icon/icon_popup_url.png' alt='icon' width=10 height=10></span><span class='"+selectYn+"'></span></a></li>");
# 																subMenuContent = $("<li class='nav-item "+activeYn+"'><a href='javascript:open_menuUrl(\""+rowObj.default_page_url+"\");' class='nav-link nav-toggle'><span class='title'>"+rowObj.menu_nm+" <img src='/com/img/common/icon/icon_popup_url.png' alt='icon' width=10 height=10></span><span class='"+selectYn+"'></span></a></li>");
# 															} else {
# 																//subMenuContent = $("<li class='nav-item "+activeYn+" padL20'><a onclick='javascript:href=\""+rowObj.default_page_url+"\"' class='nav-link nav-toggle'><span class='title'>"+rowObj.menu_nm+"</span><span class='"+selectYn+"'></span></a></li>");
# 																subMenuContent = $("<li class='nav-item "+activeYn+"'><a href='"+rowObj.default_page_url+"' class='nav-link nav-toggle'><span class='title'>"+rowObj.menu_nm+"</span><span class='"+selectYn+"'></span></a></li>");
# 															}
#
# 															//$(subMenuId).append(subMenuContent);
# 															$(thirdMenuId).append(subMenuContent);
#
# 														}
#
# 													}
# 												}
# 											}else{
# 												alert('서버와 통신중 오류가 발생하였습니다.');
# 											}
#
# 											//contentWrapper 최소높이값 조정
# 											//console.log("page-sidebar-wrapper height="+$(".page-sidebar-wrapper").height());
# 											//console.log("contentWrapper height="+$(".contentWrapper").height());
# 											var sidebar_height = 0;
# 											var contentWrapper_height = 0;
#
# 											if($(".page-sidebar-wrapper").length > 0) sidebar_height = parseInt($(".page-sidebar-wrapper").height());
#
# 											if($(".contentWrapper").length > 0){
# 												contentWrapper_height = parseInt($(".contentWrapper").height());
# 												if( sidebar_height > contentWrapper_height ){
# 													$(".contentWrapper").css('min-height',sidebar_height+'px');
# 												}
# 											}
#
# 						   				 }
# 				});
# 			}
#
# 			// TOP 메뉴 타이틀 출력
# 			function fnTopMenuTitleCreate(schBool){
# 				$.ajax({
# 					       url         : "/com/selectTopMenuTitleAjax.do?schBool="+schBool,
# 					       contentType : "application/x-www-form-urlencoded;charset=UTF-8",
# 					       type        : "post",
# 					       dataType    : "json",
# 					       data		   : "{}",
# 					       success     : function(rstData, status){
# 											if(status == "success"){
# 												var arrLength = rstData.rtnList.length;
# 												if(arrLength > 0){
#
# 													var topMenuTitleId = "";
# 													var topMenuTitle = "";
# 													var topMenuUrl = "#";
#
# 													for (var i=0; i < arrLength; i++) {
# 														var rowObj 		= rstData.rtnList[i];
#
# 														if(rowObj.top_menu_url != "") {
# 															topMenuUrl = rowObj.top_menu_url;
# 														}
#
# 														topMenuTitleId = $("#title_"+rowObj.system_cd);
# 														var className = "";
#
# 														if("false" == schBool){
# 															if(rowObj.system_cd == "ACD"){
# 																className = "active";
# 															}
#
# 															var classGap = "";
# 															if(className!="") {
# 																classGap = " ";
# 															}
# 															if(rowObj.system_nm.length > 8) {
# 																className = className+classGap+"font-transform-scaleY";
# 															}
#
# 															topMenuTitle = $("<a href='"+topMenuUrl+"' id='mainMenuLnk' class='"+className+"'>"+rowObj.system_nm+"</a>");
#
# 														}else{
# 															if(rowObj.system_cd == "ACD00148"){
#
# 																$(topMenuTitleId).addClass("active");
# 															}
# 															topMenuTitle = $("<a href='"+topMenuUrl+"' id='mainMenuLnk' class='"+className+"'>"+rowObj.system_nm+"</a>");
#
# 														}
# 														// 추가 e-마당 강조
# 														if(rowObj.system_cd == "CRO") {
# 															topMenuTitle = $("<a href='"+topMenuUrl+"' id='mainMenuLnk' class='textY'>"+rowObj.system_nm+"</a>");
# 														}
#
# 														$(topMenuTitleId).append(topMenuTitle);
#
# 														topMenuTitleId = "";
# 														topMenuTitle = "";
# 													}
# 												}
# 											}else{
# 												alert('서버와 통신중 오류가 발생하였습니다.');
# 											}
# 						   				 }
# 				});
# 			}
#
#
# 			// TOP 메뉴 타이틀 출력
# 			function fnSearchTopMenuTitleCreate(userId, schBool){
# 				$.ajax({
# 					       url         : "/com/selectTopMenuTitleAjax.do?schBool="+schBool,
# 					       contentType : "application/x-www-form-urlencoded;charset=UTF-8",
# 					       type        : "post",
# 					       dataType    : "json",
# 					       data		   : "{}",
# 					       success     : function(rstData, status){
# 											if(status == "success"){
# 												var arrLength = rstData.rtnList.length;
# 												if(arrLength > 0){
#
# 													var topMenuTitleId = "";
# 													var topMenuTitle = "";
# 													var topMenuUrl = "#";
#
# 													for (var i=0; i < arrLength; i++) {
# 														var rowObj 		= rstData.rtnList[i];
#
# 														if(rowObj.top_menu_url != "") {
# 															topMenuUrl = rowObj.top_menu_url;
# 														}
#
#
# 														topMenuTitleId = $("#title_"+rowObj.system_cd);
#
# 														var className = "";
#
# 														if("false" == schBool){
# 															if(rowObj.system_cd == "ACD"){
# 																className = "active";
#
# 															}
#
# 															var classGap = "";
# 															if(className!="") {
# 																classGap = " ";
# 															}
# 															if(rowObj.system_nm.length > 8) {
# 																className = className+classGap+"font-transform-scaleY";
# 															}
# 															topMenuTitle = $("<a href='javascript:goSearchCategory(\""+topMenuUrl+"\",\""+rowObj.system_cd+"\");' class='"+className+"'"+rowObj.system_nm+"</a>");
#
# 														}else{
# 															if(rowObj.system_cd == "ACD00148"){
#
# 																$(topMenuTitleId).addClass("active");
# 															}
# 															topMenuTitle = $("<a href='javascript:goSearchCategory(\""+topMenuUrl+"\",\""+rowObj.system_cd+"\");' class='"+className+"'>"+rowObj.system_nm+"</a>");
# 														}
#
# 														$(topMenuTitleId).append(topMenuTitle);
#
# 														topMenuTitleId = "";
# 														topMenuTitle = "";
# 													}
# 												}
# 											}else{
# 												alert('서버와 통신중 오류가 발생하였습니다.');
# 											}
# 						   				 }
# 				});
# 			}
#
# 			// TOP 메뉴 출력(권한 적용)
# 			function fnTopMenuCreate(){
# 				$.ajax({
# 					       url         : "/com/selectTopMenuAjax.do",
# 					       contentType : "application/x-www-form-urlencoded;charset=UTF-8",
# 					       type        : "post",
# 					       dataType    : "json",
# 					       data		   : "{}",
# 					       success     : function(rstData, status){
#
# 											if(status == "success"){
# 												var arrLength = rstData.rtnList.length;
# 												if(arrLength > 0){
#
# 													var menuName = "";
# 													var menuUrl = "";
# 													var topMenuContent = "";
# 													var topMenuId;
# 													var topMenuTitleId;
#
# 													for (var i=0; i < arrLength; i++) {
# 														var rowObj 		= rstData.rtnList[i];
# 														topMenuId = $("#"+rowObj.system_cd);
#
# 														menuUrl = rowObj.menu_url;
# 														menuName = rowObj.menu_nm;
#
# 														if(menuUrl=="") {
# 															//topMenuContent = $("<li style='list-style-type:none;'><a href='javascript:noAccess();' style='color:#CFCFCF;'>"+menuName+"</a></li>");
# 															topMenuContent = "";
# 														} else {
# 															if(rowObj.popup_yn=="Y") {
# 																topMenuContent = $("<li style='list-style-type:none;word-break:keep-all;word-wrap:break-word;'><a href='javascript:open_menuUrl(\""+menuUrl+"\");' id='subMenuLnk'>"+menuName+" <img src='/com/img/common/icon/icon_popup_url.png' alt='icon' width=10 height=10></a></li>");
# 															} else {
# 																topMenuContent = $("<li style='list-style-type:none;word-break:keep-all;word-wrap:break-word;'><a href='"+menuUrl+"' id='subMenuLnk'>"+menuName+"</a></li>");
# 															}
# 														}
#
# 														$(topMenuId).append(topMenuContent);
#
# 														topMenuId = "";
# 														topMenuContent = "";
# 													}
# 												}
# 											}else{
# 												alert('서버와 통신중 오류가 발생하였습니다.');
# 											}
# 						   				 }
# 				});
# 			}
#
# 			// TOP 메뉴 타이틀 출력
# 			function fnMsgUnreadCount(){
# 				$.ajax({
# 					       url         : "/com/selectMsgUnreadCountAjax.do",
# 					       contentType : "application/x-www-form-urlencoded;charset=UTF-8",
# 					       type        : "post",
# 					       dataType    : "json",
# 					       data		   : "{}",
# 					       success     : function(rstData, status){
# 											if(status == "success"){
# 												if(rstData.msgUnreadCount!="0"){
# 													$('#msgCount').html("쪽지도착("+rstData.msgUnreadCount+"건)");
# 													$('#msgCount').addClass("textR");
# 													$('#msgCount').addClass("font-bold");
# 												}
# 											}else{
# 												alert('서버와 통신중 오류가 발생하였습니다.');
# 											}
# 						   				 }
# 				});
# 			}
#
# 			function go_login(flag) {
# 				document.loginForm.target = '_self';
# 				document.loginForm.action = '/com/loginProc.do';
# 				document.loginForm.submit();
# 			}
#
# 			function go_logout(flag) {
# 				document.logoutForm.target = '_self';
# 				document.logoutForm.action = '/com/logoutProc.do';
# 				document.logoutForm.submit();
# 			}
#
# 			function go_myInfo() {
# 				document.location.href="/por/myInfo.do";
# 			}
#
# 			function go_MyMsg() {
# 				var url ="/por/myMsgReceive.do";
#
# 				document.location.href= url;
# 			}
#
# 			function go_admin() {
# 				window.open("http://www.csi.go.kr:8081/adm/index.do");
# 			}
#
# 			function go_sitemap() {
# 				alert("구성중");
# 				//document.location.href="/por/sitemap.do";
# 			}
#
# 			function open_menuUrl(url) {
# 				window.open(url,"_blank","");
# 			}
#
# 			function open_editpwd() {
# 				window.open("/por/findUserCertiPop.do",'findIdPw','width=400,height=400,menubar=no,toolbar=no,scrollbars=yes,resizable=yes');
# 			}
#
# 			function open_dashboard() {
# 				jQuery("<form target='_blank' method='post' action='/dashboard.do'></form>").appendTo('body').submit().remove();
# 			}
#
#
# 			$(function () {
# 				$(".detail-search-btn").detailSch();	// 통합검색 상세옵션보기
# 				$(".total-search-bar").selectSch();		// 통합검색 흰트 상세옵션보기
# 			});
#
# 			// 상세 검색 - Show / Hide
# 			$.fn.detailSch = function () {
# 				return this.each(function () {
# 					var $obj = $(this),
# 						$tgt = $(".detail-option-wrapper")
# 						$tgtPage = $(".top-total-search")
# 					;
#
# 					$obj.on("click", function () {
# 						if (!$obj.hasClass("on")) {
# 							$obj.addClass("on");
# 							$tgt.addClass("on");
# 							$tgtPage.addClass("detail-option-active");
# 						} else {
# 							$obj.removeClass("on");
# 							$tgt.removeClass("on");
# 							$tgtPage.removeClass("detail-option-active");
# 						}
# 					});
#
# 					$tgt.find(".btn-close").on("click", function () {
# 						$obj.removeClass("on");
# 						$tgt.removeClass("on");
# 						$tgtPage.removeClass("detail-option-active");
# 					});
# 				});
# 			};
#
# 			// 통합검색 흰트 - Show / Hide
# 			$.fn.selectSch = function () {
# 				return this.each(function () {
# 					var $obj = $(this),
# 						$tgt = $(".search-select")
# 					;
#
# 					$obj.on("click", function () {
# 						if (!$tgt.hasClass("on")) {
# 							$tgt.addClass("on");
# 						} else {
# 							$tgt.removeClass("on");
# 						}
# 					});
#
# 					$obj.on("focusout", function () {
# 						if ($tgt.hasClass("on")) {
# 							$tgt.removeClass("on");
# 						}
# 					});
# 				});
# 			};
#
#
# 			//통합검색
# 			function go_sch_search(){
#
# 			var searchTerm = $("#searchTerm").val().replaceAll("<", "&lt;").replaceAll(">", "&gt;").replaceAll("&", "&amp;").replaceAll("\"", "&quot;").replaceAll("'", "&apos;").replaceAll("\\(", "").replaceAll("\\)", "");
#
# 			setCookie("diquest",searchTerm); //최근검색어 추가
#
# 			var chkArray = new Array(); // 배열 선언
#
# 			if($('#chk_all').is(':checked')){
# 					$("#searchRange").val('all');
# 				}else{
# 					$('input:checkbox[name=rangeCheck]:checked').each(function() { // 체크된 체크박스의 value 값을 가지고 온다.
# 			            chkArray.push(this.value);
# 			        });
# 			        $('#searchRange').val(chkArray);
# 				}
#
# 				var order = $('input[name=radioInline]:checked').val();
#
# 				$("#order").val(order);
# 				$("#searchType").val('');
# 				$("#check").val('2');
# 				$('#diquestForm').attr('action', '/search/schTotalList.do');
# 				$('#diquestForm').attr('target', '_blank');
# 				$('#diquestForm').submit();
#
# 			}
#
# 			//최근검색어,인기검색어 자동완성 누르고 검색
# 			function keywordSearch(searchTerm) {
#
# 				setCookie("diquest",$("#searchTerm").val()); //최근검색어 추가
# 				$("#searchTerm").val(searchTerm);
#
# 				go_sch_search();
# 			}
#
# 			//자동완성
# 			var index=0;
# 			function autoCompletes(event){
# 				var originTag = $("#searchTerm").val();
# 				var code = event.keyCode; //키보드 이벤트 키 값
#
# 				var checkCount =0;
#
#
# 				if(code!=40 && code!=38 &&code!=13){
# 					//alert($("#searchTerm").val());
# 					$.ajax({
# 						type : "GET",
# 				        url : "/search/autoCompleteAjax.do",
# 				        data : {"keyword" :$("#searchTerm").val()},
# 				        async : false,
# 				        dataType    : "json",
# 				        error : function(){
#
# 				        },
# 				        success : function(rstData, status){
# 							var text = "";
# 							text += "<ul>";
#
# 							var arrLength = rstData.rtnList.length;
# 				        	if(arrLength > 0){
#
# 								var keyword = "";
# 								var count = "";
#
#
# 								for (var i=0; i < arrLength; i++) {
# 									var rowObj 		= rstData.rtnList[i];
#
# 									keyword = rowObj.keyword;
# 									count = rowObj.count;
#
#
# 									checkCount = arrLength+1;
#
# 									text +="<li><a href='javascript:void(0);' onclick='keywordSearch(\""+keyword+"\")';>"+keyword+"</a></li>"
#
# 									//text += "<li><a href='javascript:void(0);' onclick='keywordSearch(";
# 									//text +=  '"'+keyword+'"';
# 									//text += ");";
#
# 								}
#
# 							}else{
# 								text = "<li>검색 결과가 없습니다.</li>";
# 							}
# 				        	text += "<ul>";
#
# 				        	$("#search-select").html(text) ;
# 				        }
#
# 				    });
# 				}
#
#
# 				var len = $("#search-select > ul > li").length;//검색된 리스트 수
#
#
# 				if(len>0){  //검색결과가 하나라도 있는 경우
# 					var start = index;
# 					if(code ==40){    //아래방향키 눌렀을 때
# 						index++;
# 						if(index > len){  //마지막 인덱스 까지 간 경우
#
# 							$("#search-select > ul > li:nth-child("+(index-1)+")").css('background-color','');
#
# 							index = 0;
# 							$("input[name=searchTerm]").val(originTag);  //검색창에 처음 입력한 검색값을 넣는다.
# 							return;
# 						}else{
# 							if(index>=0){ //정상적인 경우
# 								var tagName = $.trim($("#search-select > ul > li:nth-child("+index+") a").text());
# 								$("input[name=searchTerm]").val(tagName);
# 								$("#search-select > ul > li:nth-child("+index+")").css('background-color','#D5D5D5');
# 								$("#search-select > ul > li:nth-child("+(index-1)+")").css('background-color','');
#
#
# 							}
# 							//index++;
#
# 						}
# 					}else if(code==38){
# 						index--;
# 						if(index==0){
# 							$("input[name=searchTerm]").val(originTag);
# 							$("#search-select > ul > li:nth-child("+(index+1)+")").css('background-color','');
# 						}else{
# 							if(index<0){
# 								index = len+1;
# 							}else{
# 								var tagName = $.trim($("#search-select > ul > li:nth-child("+index+") a").text());
# 								$("input[name=searchTerm]").val(tagName);
# 								$("#search-select > ul > li:nth-child("+index+")").css('background-color','#D5D5D5');
# 								$("#search-select > ul > li:nth-child("+(index+1)+")").css('background-color','');
# 							}
# 						}
#
# 					}
# 				}
#
# 			}
#
#
# 		</script>
# <script language="javascript"> <!-- LDB, 210621 추가, 세션 타임아웃에 따른 자동 로그아웃 -->
# 			var time;
#
# 			$(function() {
# 				var toMd = ""
# 				    toMd +="	<div class='modal fade' id='timeOutModal' data-backdrop='static' data-keyboard='false' style='display: none;'>"
# 					toMd +="	<div class='modal-dialog' style='width:520px;'>"
# 					toMd +="		<div class='modal-content'>"
# 					toMd +="			<div class='modal-header'>"
# 					toMd +="				<h4 class='modal-title'>로그아웃 알림</h4>"
# 					toMd +="			</div>"
# 					toMd +="			<div class='modal-body'>"
# 					toMd +="				<div class='table-top-control'>"
# 					toMd +="					<!-- 알림 시작 -->"
# 					toMd +="					<div class='notice-view'>"
# 					toMd +="						<img class='notice-view-ico' src='/com/img/common/icon/ico_view_notice.png' alt='notice'>"
# 					toMd +="						<span>장시간 사용하지 않아 </span><span id='timeoutView' class='textR'></span><span>초 후 자동 로그아웃됩니다. </span>"
# 					toMd +="					</div>"
# 					toMd +="				</div>"
# 					toMd +="				<div class='modal-footer'>"
# 					toMd +="					<button type='button' class='btn btn-danger' data-dismiss='modal' onclick='timeOutModal_choice(`r`);'>연장</button>"
# 					toMd +="					<button type='button' class='btn dark btn-outline' data-dismiss='modal' onclick='timeOutModal_choice(`c`);'>로그아웃</button>"
# 					toMd +="				</div>"
# 					toMd +="			</div>"
# 					toMd +="		</div>"
# 					toMd +="	</div>"
# 					toMd +="</div>"
#
# 				$("body").append(toMd);
#
# 				if(false) {
# 					time = 5400 -400;
# 					var timer = setInterval(function() {
#
# 						time--;
# 						if(time == 300) {
# 							go_timeOutModal();
# 						}
#
# 						$("#timeoutView").html(time);
#
# 						if(time == 0) {
# 							clearInterval(timer);
# 							autoLogout();
# 						}
# 					}, 1000);
#
# 				}
#
# 			});
#
# 			function timeOutModal_choice(type) {
# 				if(type == 'r') {
#
# 					$.ajax({
# 	                    type: "post",
# 	                    url: "/com/extSesTimeAjax.do",
# 	                    data: "",
# 	                    success: function (data) {
# 	                    	time = 5400 -400;
# 	                    },
# 	                    error: function (error) {
# 	                    	alert("에러");
# 	                        go_logout();
# 	                    }
# 	                });
# 				} else if (type == 'c') {
# 					go_logout();
# 				}
# 			}
#
# 			function go_timeOutModal() {
# 				$("#timeOutModal").modal();
# 			}
#
#
# 			function autoLogout() {
# 				$.ajax({
#                     type: "post",
#                     url: "/com/autoLogoutAjax.do",
#                     data: "",
#                     success: function (data) {
#                         if(data.isOk == "Y") {
#                         	alert("장시간 사용하지 않아 접속이 차단되었습니다. 재로그인 후 사용하시기 바랍니다.");
#                         	$("#timeOutModal").modal("hide");
#                         	window.location.href = '/index.do';
#                         } else {
#                         	go_logout();
#                         }
#                     },
#                     error: function (error) {
#                         go_logout();
#                     }
#                 });
# 			}
#
# 		</script>
# <script language="javascript">
#
# 	       	$(document).ready(function(){
# 	    		$('#page_title').html("사고사례 조회");
# 	    		$('#page_desc').html("");
#
# 	    		fnTopMenuTitleCreate("false");
# 	    		fnTopMenuCreate();
# 	    		fnLeftMenuCreate("ACD");
# 	    		if(""!="") {
# 	    			fnMsgUnreadCount();
# 	    		}
#
# 	    		/* 날짜 시작일 종료일 체크(테스트중)
#
# 	    		var start_date_div = $('#start_ymd');//document.getElementById('start_ymd');
# 	    		var end_date_div = $('#end_ymd');//document.getElementById('end_ymd');
#
# 	    		if(start_date_div != null && end_date_div != null) {
#
# 	    		    if($('#start_ymd').val()!="") {
# 	    		    	alert("2:"+$("#start_ymd").val());
# 	    		    	$('.date-picker').datepicker();
# 	    		    	$('.date-picker').datepicker("option", "minDate", $("#start_ymd").val());
# 	    		    	$('.date-picker').datepicker("option", "onClose", function ( selectedDate ) {
# 	    		    		$('.date-picker').datepicker( "option", "maxDate", selectedDate );
# 		    		    });
#
# 	    		    }
#
# 	    		    if($('#end_ymd').val()!="") {
# 	    		    	alert("3:"+$("#end_ymd").val());
# 	    		    	$('.date-picker').datepicker();
# 		    			$('.date-picker').datepicker("option", "maxDate", $("#end_ymd").val());
# 		    		    $('.date-picker').datepicker("option", "onClose", function ( selectedDate ) {
# 		    		    	$('.date-picker').datepicker( "option", "minDate", selectedDate );
# 		    		    });
# 	    		    }
#
# 		    		$('#start_ymd').on('change', function() {
# 		    			alert("4:"+$("#start_ymd").val());
# 		    			$('.date-picker').datepicker();
# 		    			$('.date-picker').datepicker("option", "minDate", $("#start_ymd").val());
# 		    			$('.date-picker').datepicker("option", "onClose", function ( selectedDate ) {
# 		    				$('.date-picker').datepicker( "option", "maxDate", selectedDate );
# 		    		    });
# 		    		});
#
# 		    		$('#end_ymd').on('change', function() {
# 		    			alert("5:"+$("#end_ymd").val());
# 		    			$('.date-picker').datepicker();
# 		    			$('.date-picker').datepicker("option", "maxDate", $("#end_ymd").val());
# 		    			$('.date-picker').datepicker("option", "onClose", function ( selectedDate ) {
# 		    				$('.date-picker').datepicker( "option", "minDate", selectedDate );
# 		    		    });
# 		    		});
# 	    		}
# 	    		*/
#
# 	    	});
#
#
# 		</script>
# </link></meta></head>
# <!-- head 끝 -->
# <body class="page-content-white page-front page-renewal top-total-search" onkeyup="tabKeyEvent()"> <!-- 가로 꽉찬화면은 class="page-full-screen"를 추가합니다. -->
# <!-- skip To Content 시작 -->
# <div id="skipToContent" tabindex="-999">
# <a href="#content">본문 바로가기</a>
# </div>
# <script>
# 		$('#skipToContent a').on('focus', function(){
# 			$(this).stop().animate({"top":0, "opacity":1});
# 		});
# 		$('#skipToContent a').on('click', function(){
# 			$(this).stop().animate({"top":"-30px", "opacity":0});
# 		});
# 		$('#skipToContent a').on('focusout', function(){
# 			$(this).stop().animate({"top":"-30px", "opacity":0});
# 		});
#
# 		function tabKeyEvent() {
# 			var focuElm = document.activeElement.id;
# 			var code = event.charCode || event.keyCode;
#
# 			//alert(focuElm+"/"+code);
#
# 			if((focuElm == "mainMenuLnk" || focuElm == "subMenuLnk") && code == "9") {
# 				if(!document.getElementById("subMenu").classList.contains('on')) {
# 					document.getElementById("subMenu").className += ' on';
# 				}
# 			} else {
# 				if(document.getElementById("subMenu").classList.contains('on')) {
# 					document.getElementById("subMenu").classList.remove('on');
# 				}
# 			}
#
#
# 		}
#
#
#
# 	</script>
# <!-- skip To Content 끝 -->
# <div class="page-wrapper">
# <!-- 글로벌 시작 -->
# <div class="page-header navbar navbar-fixed-top">
# <div class="page-header-inner">
# <div class="page-logo">
# <a href="/index.do">
# <span class="logo-default"><img alt="건설공사안전관리종합정보망 로고" src="/com/img/main_renewal/header/logo.png"/></span>
# </a>
# </div>
# <!-- 로그아웃 했을때 시작 -->
# <div class="top-menu">
# <form action="#" id="loginForm" method="post" name="loginForm">
# <input id="bbs_id" name="bbs_id" type="hidden" value=""/>
# <input id="bbt_no" name="bbt_no" type="hidden" value=""/>
# <input id="case_no" name="case_no" type="hidden" value="27442"/>
# <input id="nextUrl" name="nextUrl" type="hidden" value="/acd/acdCaseView.do"/>
# <ul class="nav navbar-nav pull-right">
# <li class="dropdown dropdown-extended dropdown-user">
# <div class="form-inline">
# <div class="form-group">
# <label class="control-label visible-ie8 visible-ie9" for="user_id">아이디</label>
# <div class="input-icon">
# <i class="fa fa-user"></i>
# <input autocomplete="off" class="form-control" id="user_id" maxlength="20" name="user_id" placeholder="아이디" style="width: 120px;" type="text" value=""/>
# </div>
# </div>
# <div class="form-group">
# <label class="control-label visible-ie8 visible-ie9" for="pswd">비밀번호</label>
# <div class="input-icon">
# <i class="fa fa-lock"></i>
# <input autocomplete="off" class="form-control" id="pswd" name="pswd" onkeydown="if (event.keyCode == 13) go_login('N')" placeholder="비밀번호" style="width: 120px;" type="password" value=""/>
# </div>
# </div>
# </div>
# </li>
# <li class="dropdown dropdown-extended dropdown-inbox">
# <a class="login-btn" href="javascript:go_login('N')">로그인</a>
# <a class="user-btn" href="/por/realNameCerti.do">회원가입</a>
# <a class="idpw-btn" href="" onclick="open_editpwd()">아이디/비밀번호 찾기</a>
# </li>
# <li class="dropdown dropdown-extended dropdown-inbox">
# <a class="dropdown-toggle top-btn btn-sitemap" href="/por/about004.do">사이트맵</a>
# </li>
# </ul>
# </form>
# </div>
# <!-- 로그아웃 했을때 끝 -->
# <form id="diquestForm" method="post" name="diquestForm">
# <input id="order" name="order" type="hidden" value="">
# <input id="searchType" name="searchType" type="hidden" value=""/>
# <input name="researchKeyword" type="hidden" value=""/>
# <input id="check" name="researchCheck" type="hidden" value=""/>
# <input name="researchWatchKeyword" type="hidden" value=""/>
# <!-- 통합검색 시작 -->
# <div class="total-search-wrapper">
# <div class="input-group">
# <input alt="통합검색입력창" autocomplete="off" class="form-control total-search-bar" id="searchTerm" name="searchTerm" onclick="autoCompletes(event);" onkeydown="if(event.keyCode == 13) go_sch_search();" onkeyup="autoCompletes(event);" placeholder="검색어를 입력하세요." title="통합검색입력창" type="text" value=""/>
# <span class="input-group-btn">
# <button class="btn search-btn" onclick="go_sch_search()" title="통합검색버튼" type="button"><i alt="통합검색버튼" class="fa fa-search"></i></button>
# </span>
# </div>
# <div class="detail-search-wrapper">
# <div class="form-inline">
# <div class="form-group">
# <label class="mt-checkbox-outline">
# 											  <input name="researchFlag" type="checkbox" value="1"/> 결과내 검색
# 										</label>
# </div>
# <div class="form-group">
# <button alt="상세검색버튼" class="btn dark detail-search-btn" onclick="javascript:;" type="button">상세검색</button>
# </div>
# </div>
# </div>
# <!-- 통합검색 흰트 시작 -->
# <div class="search-layer">
# <div class="search-select" id="search-select">
# </div>
# </div>
# <!-- 통합검색 흰트 끝 -->
# </div>
# <!-- 통합검색 끝 -->
# <!-- 상세검색 시작 -->
# <div class="detail-option-wrapper">
# <table class="table">
# <colgroup>
# <col width="20%"/>
# <col width="auto"/>
# </colgroup>
# <tbody>
# <tr>
# <td class="td-head">검색범위</td>
# <td class="t-left">
# <div class="mt-checkbox-inline">
# <input id="searchRange" name="searchRange" type="hidden" value=""/>
# <label class="mt-checkbox mt-checkbox-outline">
# <input id="chk_all" type="checkbox" value="all"/> 전체
# 												<span></span>
# </label>
# <label class="mt-checkbox mt-checkbox-outline">
# <input class="chk" name="rangeCheck" type="checkbox" value="TITLE"/> 제목
# 												<span></span>
# </label>
# <label class="mt-checkbox mt-checkbox-outline">
# <input class="chk" name="rangeCheck" type="checkbox" value="CONTENT"/> 내용
# 												<span></span>
# </label>
# <label class="mt-checkbox mt-checkbox-outline">
# <input class="chk" name="rangeCheck" type="checkbox" value="FILE"/> 첨부파일
# 												<span></span>
# </label>
# <label class="mt-checkbox mt-checkbox-outline">
# <input class="chk" name="rangeCheck" type="checkbox" value="USER"/> 등록자
# 												<span></span>
# </label>
# </div>
# </td>
# </tr>
# <tr>
# <td class="td-head">검색기간</td>
# <td class="t-left">
# <div class="form-inline">
# <div class="form-group">
# <div class="form-inline">
# <div class="input-group input-medium date date-picker" data-date="" data-date-format="yyyy-mm-dd" data-date-viewmode="years">
# <input class="form-control tYMD" id="note_ymd_from" name="note_ymd_from" title="시작일" type="text" value=""/>
# <span class="input-group-btn">
# <button alt="시작일-달력선택" class="btn dark" type="button">
# <i class="fa fa-calendar"></i>
# </button>
# </span>
# </div>
# <span> ~ </span>
# <div class="input-group input-medium date date-picker" data-date="" data-date-format="yyyy-mm-dd" data-date-viewmode="years">
# <input class="form-control tYMD" id="note_ymd_to" name="note_ymd_to" title="종료일" type="text" value=""/>
# <span class="input-group-btn">
# <button alt="종료일-달력선택" class="btn dark" type="button">
# <i class="fa fa-calendar"></i>
# </button>
# </span>
# </div>
# </div>
# </div>
# <button alt="1주일선택" class="btn dark" onclick="dayCheck('oneWeek');" type="button">1주일</button>
# <button alt="1개월선택" class="btn dark" onclick="dayCheck('oneMonth');" type="button">1개월</button>
# <button alt="3개월선택" class="btn dark" onclick="dayCheck('threeMonth');" type="button">3개월</button>
# </div>
# </td>
# </tr>
# <tr>
# <td class="td-head">검색방법</td>
# <td class="t-left">
# <div class="mt-radio-inline">
# <label class="mt-radio mt-radio-outline">
# <input name="searchRadioInline" type="radio" value="or"/> 하나라도 포함된 결과(OR)
# 												<span></span>
# </label>
# <label class="mt-radio mt-radio-outline">
# <input name="searchRadioInline" type="radio" value="and"/> 모두 포함된 결과(AND)
# 												<span></span>
# </label>
# </div>
# </td>
# </tr>
# </tbody>
# </table>
# <div class="close-btn-group">
# <button alt="닫기버튼" class="btn btn-close" type="button"><img alt="닫기버튼" src="/com/img/common/icon/remove-icon-small.png"/>닫기</button>
# </div>
# </div>
# <!-- 상세검색 끝 -->
# </input></form>
# <!-- 메뉴 시작 -->
# <div class="page-menu-wrapper hor-menu">
# <ul class="nav navbar-nav all-menu-none" id="nav"> <!-- 20200629수정 : all-menu-none 클래스 추가 -->
# <!-- <li class="all-menu"><div class="all-menu-btn"><a href="#"></a></div></li> -->
# <li class="title" id="title_POR"></li>
# <li class="title" id="title_DFS"></li>
# <li class="title" id="title_SMP"></li>
# <li class="title" id="title_LEV"></li>
# <li class="title" id="title_NMS"></li>
# <li class="title" id="title_ACD"></li>
# <li class="title" id="title_HRA"></li>
# <li class="title" id="title_SPT"></li>
# <li class="title" id="title_CTS"></li>
# <li class="title" id="title_CRO"></li>
# <li class="title" id="title_API"></li>
# <li class="title" id="title_COM"></li>
# </ul>
# </div>
# <div class="navi-depth all-menu-none" id="subMenu"> <!-- 20200629수정 : all-menu-none 클래스 추가 -->
# <div class="depth-group">
# <div class="depth-align">
# <ul class="depth-ul 2depth" id="POR"></ul>
# <ul class="depth-ul 2depth" id="DFS"></ul>
# <ul class="depth-ul 2depth" id="SMP"></ul>
# <ul class="depth-ul 2depth" id="LEV"></ul>
# <ul class="depth-ul 2depth" id="NMS"></ul>
# <ul class="depth-ul 2depth" id="ACD"></ul>
# <ul class="depth-ul 2depth" id="HRA"></ul>
# <ul class="depth-ul 2depth" id="SPT"></ul>
# <ul class="depth-ul 2depth" id="CTS"></ul>
# <ul class="depth-ul 2depth" id="CRO"></ul>
# <ul class="depth-ul 2depth" id="API"></ul>
# <ul class="depth-ul 2depth" id="COM"></ul>
# </div>
# </div>
# </div>
# <!-- 전체메뉴 끝 -->
# </div>
# </div>
# <!-- 글로벌 끝 -->
# <!-- 헤더 & 컨텐츠 분할 시작 -->
# <div class="clearfix"> </div>
# <!-- 헤더 & 컨텐츠 분할 끝 -->
# <!-- container 시작 -->
# <div class="page-container">
# <!-- 페이지 레이아웃 시작 -->
# <div class="page-content-wrapper">
# <div class="page-content" id="contents">
# <!-- 서브 비주얼 시작 -->
# <div class="page-sub-visual sub-visual-type-01">
# <div class="page-sub-visual-inner"></div>
# </div>
# <!-- 서브 비주얼 끝 -->
# <!-- 페이지바 시작 -->
# <div class="page-bar hor-menu">
# <div class="page-bar-inner">
# <!-- 카테고리 시작 -->
# <ul class="page-breadcrumb">
# <li class="page-breadcrumb-home"><span></span></li><li><span>건설사고</span></li><li><span data-close-others="true">사고사례</span></li><li><span data-close-others="true">사고사례 조회</span></li></ul>
# <!-- 카테고리 끝 -->
# <!-- 컨텐츠 옵션 시작 -->
# <ul class="page-options">
# <li class="page-options-print tooltips" data-container="body" data-original-title="프린트" data-placement="bottom" style="line-height: 0px;"><a id="print-preview"></a></li>
# </ul>
# <!-- 컨텐츠 옵션 끝 -->
# </div>
# </div>
# <!-- 페이지바 끝 -->
# <form action="" id="menu" method="post" name="menu">
# <input name="menu_id" type="hidden" value=""/>
# <input name="nextUrl" type="hidden" value=""/>
# <input name="p_dign_gbn" type="hidden" value=""/>
# <!-- 왼쪽메뉴 시작 -->
# <div class="page-sidebar-wrapper">
# <div class="page-sidebar navbar-collapse collapse">
# <ul class="page-sidebar-menu page-header-fixed" data-auto-scroll="true" data-keep-expanded="false" data-slide-speed="200" id="pageSidebarMenu">
# <li class="heading">
# <h2 class="heading-title">건설사고</h2>
# </li>
# </ul>
# </div>
# </div>
# <!-- 왼쪽메뉴 끝 -->
# </form>
# <!-- 통합메세지 발송 -->
# <form id="form_sendMsgPop" method="post" name="form_sendMsgPop">
# <input name="inst_nm" type="hidden"/>
# <input name="inst_chrgr_nm" type="hidden"/>
# <input name="hp_no" type="hidden"/>
# <input name="inst_chrgr_id" type="hidden"/>
# </form>
# <!-- 그룹웨어 팝업창을 위한 form -->
# <form id="form_gwPop" method="post" name="form_gwPop">
# <input name="key" type="hidden"/>
# <input name="code1" type="hidden"/>
# </form>
# <!-- 컨텐츠 시작 -->
# <div class="contentWrapper" id="divRight">
# <script src="https://map.vworld.kr/js/vworldMapInit.js.do?apiKey=BDA4A4D1-F7DC-3C0F-B569-DFC820D3A957" type="text/javascript"></script>
# <script>var vworldApiKey = 'BDA4A4D1-F7DC-3C0F-B569-DFC820D3A957';</script>
# <script src="/com/js/vworldMap.js?ver=1.0" type="text/javascript"></script>
# <script src="/com/js/exif.js" type="text/javascript"></script>
# <script language="javascript">
#
# var mainYnTimeout = null;
#
# $(document).ready(function() {
# 		var params = {
# 			biz_id		: $('#biz_id').val(),
# 			accd_no		: $('#accd_no').val(),
# 			popup_yn	: $('#popup_yn').val(),
# 			menu_id		: $('#menu_id').val(),
# 			start_ymd	: $('#start_ymd').val(),
# 			end_ymd		: $('#end_ymd').val(),
# 			search_key	: $('#search_key').val(),
# 			search_val	: $('#search_val').val(),
# 			page_count	: $('#page_count').val(),
# 		}
#
# 		$("#tab").load('/acd/photoInc.do', params);
#
# 		$('input[name="main_yn"]').on('click', function(){
# 			var value = "N";
# 			if($(this).prop("checked")){
# 				value = "Y";
# 			}
# 			if(isMainSubmit){
# 				$(this).prop("checked", !$(this).prop("checked"));
# 			}
# 			clearTimeout(mainYnTimeout);
# 			mainYnTimeout = setTimeout(function () {
# 				updateMainPublic(value);
# 			}, 500);
# 		})
# 	});
#
# 	function goEdit() {
# 		$('#main').attr('action','/ia/initialCaseEdit.do');
# 		$('#main').attr('target','_self');
# 		$('#main').submit()
# 	}
#
# 	function goDelete() {
#
# 		//add v9user
# 		if(gfn_isV9user("N")){ return; }
#
# 		if(confirm("사고사례를 삭제하시겠습니까?")==true) {
# 			document.main.action_type.value="DELETE";
# 			$('#main').attr('action','/ia/acdCaseProc.do');
# 			$('#main').attr('target','_self');
# 			$('#main').submit()
# 		}
# 	}
#
#
# 	function goList() {
# 		$('#main').attr('action', '/acd/acdCaseList.do');
# 		$('#main').attr('target','_self');
# 		$('#main').submit();
# 	}
#
#
# 	var isMainSubmit = false;
# 	// 메인 공개 여부 수정 : AJAX
# 	function updateMainPublic(mainYn){
#
# 		//add v9user
# 		if(gfn_isV9user("N")){ return; }
#
# 		if(isMainSubmit){
# 			messageBox.alert("이미 공개 여부 수정중입니다.");
# 			return;
# 		}
# 		isMainSubmit = true;
#
# 		$.ajax({
# 			type: "post",
# 			url: "/acd/updateMainPublicAjax.do",
# 			data: {
# 				accd_no : $('input[name="accd_no"]').val(),
# 				main_yn : mainYn
# 			},
# 			dataType: "json",
# 			success: function (result, status) {
# 				if(status == "success"){
# 					updateMainPublicCallback(result);
# 				}else{
# 					messageBox.alert("서버와 통신중 오류가 발생하였습니다.");
# 				}
# 			},
# 			error: function(error){
# 				if(error.status == "999"){
#                     alert("해당 계정은 조회만 가능합니다.");
#                 }else{
#                     alert("에러");
#                 }
# 			},
# 			complete : function (result) {
# 				isMainSubmit = false;
# 			}
# 		});
# 	}
#
# 	// 메인 공개 여부 수정 : CALLBACK
# 	function updateMainPublicCallback(data){
# 		if(!data){
# 			return
# 		}
# 		if(data.isOk == "Y"){
# 			if(data.mainYn == "Y"){
# 				messageBox.alert("공개로 변경되었습니다.");
# 			}else{
# 				messageBox.alert("비공개로 변경되었습니다.");
# 			}
# 		}else{
# 			messageBox.alert(data.errMsg);
# 		}
# 		console.log(data);
# 	}
#
# </script>
# <section id="content">
# <h1 class="page-title">사고사례</h1>
# <div style="text-align: end;">페이지 주소 : https://www.csi.go.kr/acd/acdCaseView.do?case_no=27442</div>
# <form id="tabForm" method="post" name="tabForm">
# <input name="tab_index" type="hidden" value=""/>
# <input name="act" type="hidden" value=""/>
# </form>
# <form id="main" method="post" name="main">
# <input id="biz_id" name="biz_id" type="hidden" value="acdDB"/>
# <input id="action_type" name="action_type" type="hidden" value=""/>
# <input id="case_no" name="case_no" type="hidden" value="27442"/>
# <input id="accd_no" name="accd_no" type="hidden" value="202400002213"/>
# <input id="menu_id" name="menu_id" type="hidden" value="ACD00148"/>
# <input id="start_ymd" name="start_ymd" type="hidden" value=""/>
# <input id="end_ymd" name="end_ymd" type="hidden" value=""/>
# <input id="search_key" name="search_key" type="hidden" value=""/>
# <input id="search_val" name="search_val" type="hidden" value=""/>
# <input id="page_count" name="page_count" type="hidden" value="1"/>
# <input id="file_no" name="file_no" type="hidden" value=""/>
# <div class="contentsRow">
# <table class="table table-bordered">
# <colgroup>
# <col width="10%">
# <col width="10%">
# <col width="32%"/>
# <col width="16%"/>
# <col width="32%"/>
# </col></col></colgroup>
# <tbody>
# <tr>
# <td class="td-head" colspan="2">사고명</td>
# <td class="t-left" colspan="3">창원시 성산자원회수시설 2호기 대보수사업 철골전도</td>
# </tr>
# <tr>
# <td class="td-head" colspan="2">발생일시</td>
# <td class="t-left">2024-05-11 오후 03:32</td>
# <td class="td-head">사고인지 시간</td>
# <td class="t-left">휴일근무 - </td>
# </tr>
# <tr>
# <td class="td-head" colspan="2">공공/민간 구분</td>
# <td class="t-left">공공</td>
# <td class="td-head">기상상태</td>
# <td class="t-left">
# <div class="form-inline">
# <span class="input-group-label">
# <label class="control-label padR5">날씨 : 흐림</label>
# </span>
# <span class="input-group-label">
# <label class="control-label padL20 padR5">기온 : 18℃</label>
# </span>
# <span class="input-group-label">
# <label class="control-label padL20 padR5">습도 : 61%</label>
# </span>
# </div>
# </td>
# </tr>
# <tr>
# <td class="td-head" colspan="2">시설물 종류</td>
# <td class="t-left" colspan="3">산업환경설비 - 환경시설 - 소각장</td>
# </tr>
# <tr>
# <td class="td-head" rowspan="2">사고유형</td>
# <td class="td-head">인적사고</td>
# <td class="t-left">물체에 맞음</td>
# <td class="td-head">보호(방호)조치여부</td>
# <td class="t-left">
# <span class="input-group-label">
# <label class="control-label padL5 padR5">안전방호 :</label>
# </span>
# 							조치<span class="input-group-label"><label class="control-label padL5"></label></span>
# 							/
# 							<span class="input-group-label">
# <label class="control-label padL5 padR5">개인보호 :</label>
# </span>
# 							조치</td>
# </tr>
# <tr>
# <td class="td-head">물적사고</td>
# <td class="t-left" colspan="3">없음</td>
# </tr>
# <tr>
# <td class="td-head" rowspan="3">사고분류</td>
# <td class="td-head">공종</td>
# <td class="t-left" colspan="3">기계설비 &gt; 기계설비공사</td>
# </tr>
# <tr>
# <td class="td-head">사고객체</td>
# <td class="t-left" colspan="3">부재 &gt; 철골부재</td>
# </tr>
# <tr>
# <td class="td-head">작업프로세스</td>
# <td class="t-left" colspan="3">설치작업</td>
# </tr>
# <tr>
# <td class="td-head" rowspan="2">사고위치</td>
# <td class="td-head">장소</td>
# <td class="t-left" colspan="3">소각장 /
# 						내부</td>
# </tr>
# <tr>
# <td class="td-head">부위</td>
# <td class="t-left" colspan="3">철골부재 /
# 						하부(아래)</td>
#
# </tr>
# <tr>
# <td class="td-head" colspan="2">사고경위</td>
# <td class="t-left" colspan="3">재해자 장00씨가 철골 거더 설치 중 가조립물 임의해체로 철골이 넘어지며 철골부재가 허벅지를 충격한 사고</td>
# </tr>
# <tr>
# <td class="td-head" colspan="2">사고원인</td>
# <td class="t-left" colspan="3">
#
# 								* 주원인
# 								 : 작업순서 미준수</td>
# </tr>
# <tr>
# <td class="td-head" colspan="2">구체적 사고원인</td>
# <td class="t-left" colspan="3">철골 설치 중 철골을 지지하던 가조립물(고정용강관비계) 임의해체에 따른 설치 중인 철골의 전도</td>
# </tr>
# <tr>
# <td class="td-head" rowspan="4">피해상황</td>
# <td class="td-head">사망자수(명)</td>
# <td class="t-left" colspan="3">
# <div class="form-inline">
# <div class="input-group col-md-2 col-xs-2 col-sm-2">
# <span class="input-group-label">
# <label class="control-label padL20 padR5">내국인 :</label>
# </span>
# 									0명
# 								</div>
# <div class="input-group col-md-2 col-xs-2 col-sm-2">
# <span class="input-group-label">
# <label class="control-label padL20 padR5">외국인 :</label>
# </span>
# 									0명
# 								</div>
# </div>
# </td>
# </tr>
#
# <tr>
# <td class="td-head">부상자수(명)</td>
# <td class="t-left" colspan="3">
# <div class="form-inline">
# <div class="input-group col-md-2 col-xs-2 col-sm-2">
# <span class="input-group-label">
# <label class="control-label padL20 padR5">내국인 :</label>
# </span>
# 									1명
# 								</div>
# <div class="input-group col-md-2 col-xs-2 col-sm-2">
# <span class="input-group-label">
# <label class="control-label padL20 padR5">외국인 :</label>
# </span>
# 									0명
# 								</div>
# </div>
# </td>
# </tr>
# <tr>
# <td class="td-head">피해금액</td>
# <td class="t-left" colspan="3">
# 							피해없음</td>
# </tr>
# <tr>
# <td class="td-head">피해내용</td>
# <td class="t-left" colspan="3">
# 							없음</td>
# </tr>
# <tr>
# <td class="td-head" colspan="2">사고신고사유</td>
# <td class="t-left" colspan="3">
# 							3일이상 휴업이 필요한 부상</td>
# </tr>
# <tr>
# <td class="td-head" colspan="2">사고발생후 조치사항</td>
# <td class="t-left" colspan="3">
# 							사고발생: 15시32분,  15시40분 병원 이송, 고용노동부 등 관련기관 보고(16시), 발주처 1차조사(17시), 2차조사(익일10시)</td>
# </tr>
# <tr>
# <td class="td-head" colspan="2">재발방지대책</td>
# <td class="t-left" colspan="3">
# 							철골 전도 방지를 위해 철골 설치 전 가조립물 해체금지 등 교육 실시, 관리감독 강화</td>
# </tr>
# </tbody>
# </table>
# </div>
# <h1 class="page-title-2depth">현장특성</h1>
# <div class="contentsRow">
# <table class="table table-bordered" style="height:1px">
# <colgroup>
# <col width="15%"/>
# <col width="35%"/>
# <col width="15%"/>
# <col width="35%"/>
# </colgroup>
# <tbody>
# <tr>
# <td class="td-head">시군구 정보</td>
# <td class="t-left">경상남도
# 								창원시 성산구</td>
# </tr>
# <tr>
# <td class="td-head">공사종류</td>
# <td class="t-left">산업환경설비 / 환경시설 / 소각장</td>
# </tr>
# <tr>
# <td class="td-head">공사비</td>
# <td class="t-left">
# <div class="form-inline">
# <div class="input-group">
# <span class="input-group-label">
# <label class="control-label padR5">500억 ~ 1,000억원 미만</label>
# </span>
# </div>
# <div class="input-group">
# <span class="input-group-label">
# <label class="control-label padL20 padR5">(해당공종 : 20억 ~ 50억원 미만)</label>
# </span>
# </div>
# </div>
# </td>
# </tr>
# <tr>
# <td class="td-head">낙찰률</td>
# <td class="t-left">
# <div class="form-inline">
# <span class="input-group-label">
# <label class="control-label padR5">90% 이상</label>
# </span>
# </div>
# </td>
# </tr>
# <tr>
# <td class="td-head">공사기간</td>
# <td class="t-left">
# <div class="form-inline">
# <div class="input-group">
# <span class="input-group-label">
# <label class="control-label padR5">2022-11-30 ~ 2024-11-28</label>
# </span>
# </div>
# <div class="input-group">
# <span class="input-group-label">
# <label class="control-label padL20 padR5">(해당공종 : 2023-05-31 ~ 2024-11-28)</label>
# </span>
# </div>
# </div>
# </td>
# </tr>
# <tr>
# <td class="td-head">공정률</td>
# <td class="t-left">
# <div class="form-inline">
# <span class="input-group-label">
# <label class="control-label padR5">70~79%</label>
# </span>
# </div>
# </td>
# </tr>
# <tr>
# <td class="td-head">작업자수</td>
# <td class="t-left">
# <div class="form-inline">
# <div class="input-group">
# 									50~99인</div>
# </div>
# </td>
# </tr>
# <tr>
# <td class="td-head">안전관리계획</td>
# <td class="t-left">
# 							대상현장(1/2종외)</td>
# </tr>
# <tr>
# <td class="td-head">설계안전성검토</td>
# <td class="t-left">
# 							대상</td>
# </tr>
# <tr>
# <td class="td-head">해체계획서</td>
# <td class="t-left">
# 							대상</td>
# </tr>
# </tbody>
# </table>
# </div>
# <h1 class="page-title-2depth">사고조사</h1>
# <div class="contentsRow">
# <table class="table table-bordered" style="height:1px">
# <colgroup>
# <col width="15%"/>
# <col width="auto"/>
# </colgroup>
# <tbody>
# <tr>
# <td class="td-head">사고조사방법</td>
# <td class="t-left">
# 							일반조사</td>
# </tr>
# <tr>
# <td class="td-head">위원회조사필요성</td>
# <td class="t-left">
# </td>
# </tr>
# <tr>
# <td class="td-head">위원회구성(안)</td>
# <td class="t-left">
# </td>
# </tr>
# <tr>
# <td class="td-head">향후조치계획</td>
# <td class="t-left">
# 							현장 전 근로자 및 관리자 특별안전 교육 / 사고관련 위험성평가 실시</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="table-bottom-control">
# <button class="btn dark" onclick="goList()" type="button"><img alt="icon" src="../com/img/common/icon/ico_btn_list.png"/>목록</button>
# </div>
# <!-- 테이블 끝 -->
# </form>
# <div id="tab"></div>
# <div id="modal"></div>
# <div aria-hidden="true" class="modal fade in" id="basic" role="basic" style="display: none;" tabindex="-1">
# <div class="modal-dialog" style="width:80%;">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button"></button>
# <h4 class="modal-title"></h4>
# </div>
# <div class="modal-body">
# </div>
# <div class="modal-footer">
# <button class="btn dark btn-outline" data-dismiss="modal" type="button">Close</button>
# </div>
# </div>
# </div>
# </div>
# </section></div>
# </div>
# <!-- 컨텐츠 끝 -->
# </div>
# </div>
# <!-- 페이지 레이아웃 끝 -->
# </div>
# <!-- container 끝 -->
# <!-- footer 시작 -->
# <div class="page-footer">
# <div class="page-footer-inner">
# <div class="page-footer-logo">
# <img alt="국토교통부" src="/com/img/main_renewal/footer/logo_footer.png">
# </img></div>
# <div class="page-footer-container">
# <span class="address">(우)52856 경상남도 진주시 에나로 128번길 24 국토안전관리원 </span><span class="address marL10" style="font-size:13px;"> 1588-8788</span><br/>
# <span class="copyright">Copyright (c) Ministry of Land, Infrastructure and Transport. All Rights reserved.</span></div>
# <div class="page-footer-link">
# <ul class="page-footer-info">
# <li><a href="/por/serviceinfo.do?bbt_no=335">이용약관</a></li>
# <li><a href="/por/privacyPolicy.do" style="color:red; font-size: 14.4px; font-weight: bold;">개인정보 처리방침</a></li>
# <li><a href="/por/serviceinfo.do?bbt_no=337">공공데이터 이용정책</a></li>
# <li><a href="/por/serviceinfo.do?bbt_no=338">이메일주소 무단 수집 거부</a></li>
# <li><a href="http://stat.molit.go.kr/portal/quality/qualityCenterWrite.do?system_id=S0066">품질오류신고</a></li>
# <li><a href="http://stat.molit.go.kr/portal/quality/qualityCenterList.do?system_id=S0066">품질오류신고확인</a></li>
# </ul>
# <div class="page-footer-institution">
# <div class="page-footer-select-set">
# <div class="select-container">
# <label for="relationSite" style="display: none;">관련사이트 링크 바로가기</label>
# <select class="bs-select form-control" id="relationSite" onchange="if(this.value != '') window.open(this.value);">
# <option value="">::: 관련사이트 링크 바로가기 :::</option>
# <option alt="새창이동" value="http://www.molit.go.kr/">국토교통부</option>
# <option alt="새창이동" value="http://www.kalis.or.kr/">국토안전관리원(KALIS)</option>
# <option alt="새창이동" value="http://www.fms.or.kr/">시설물통합정보시스템(FMS)</option>
# <option alt="새창이동" value="http://www.kiscon.net/">건설산업지식정보시스템(KISCON)</option>
# <option alt="새창이동" value="https://www.jis.go.kr/">지하안전정보시스템(JIS)</option>
# <option alt="새창이동" value="https://bigtori.kalis.or.kr/">국토안전 빅데이터 개방 포털(Bigtori)</option>
# </select>
# </div>
# <button alt="이동버튼" class="btn dark" onclick="moveUrl()" type="button">이동</button>
# </div>
# </div>
# </div>
# </div>
# <div class="scroll-to-top">
# <i class="icon-arrow-up"></i>
# </div>
# </div>
# <!-- footer 끝 -->
#
# <div id="divCommModal"></div>
# </body>
# </html>

# %%
import requests
from bs4 import BeautifulSoup
response = requests.get("https://www.letskorail.com/ebizprd/EbizPrdTicketPr21111_i1.do")
html = response.text
soup = BeautifulSoup(html,'html.parser')
soup.select('tbody > tr')
# Out:
# []
